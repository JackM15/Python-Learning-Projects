# %%
import pandas

# %%
#Open a csv file and read it with the index set as the ID column
csvopenage = pandas.read_csv("supermarkets.csv",index_col="ID")
#show the csv 
csvopenage
# Out:
#             Address            City             State Country          Name  \
# ID
# 1      3666 21st St   San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St   San Francisco  California 94114     USA   Super River
# 4      3995 23rd St   San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St   San Francisco        California     USA       Sanchez
# 6   551 Alvarado St   San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#Open a json file

# %%
jsonopenage = pandas.read_json("supermarkets.json")
#show the json file
jsonopenage
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
#Open an excel file and specify the sheet
excelopenage = pandas.read_excel("supermarkets.xlsx", sheetname=[0])
#show the excel file
excelopenage
# Out:
# {0:    ID          Address            City             State Country  \
#  0   1     3666 21st St   San Francisco          CA 94114     USA
#  1   2   735 Dolores St   San Francisco          CA 94119     USA
#  2   3      332 Hill St   San Francisco  California 94114     USA
#  3   4     3995 23rd St   San Francisco          CA 94114     USA
#  4   5  1056 Sanchez St   San Francisco        California     USA
#  5   6  551 Alvarado St   San Francisco          CA 94114     USA
#
#    Supermarket Name  Number of Employees
#  0          Madeira                    8
#  1      Bready Shop                   15
#  2      Super River                   25
#  3       Ben's Shop                   10
#  4          Sanchez                   12
#  5       Richvalley                   20  }

# %%
#Opening a text file seperated by commas
opentextfilecsv = pandas.read_csv("supermarkets_commas.txt",index_col="ID")
opentextfilecsv
# Out:
#             Address            City             State Country          Name  \
# ID
# 1      3666 21st St   San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St   San Francisco  California 94114     USA   Super River
# 4      3995 23rd St   San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St   San Francisco        California     USA       Sanchez
# 6   551 Alvarado St   San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#Opening a text file seperated by semi colons.
opensemicolontextfile = pandas.read_csv("supermarkets_semi-colons.txt", sep=";", index_col="ID")
opensemicolontextfile
# Out:
#             Address            City             State Country          Name  \
# ID
# 1      3666 21st St   San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St   San Francisco  California 94114     USA   Super River
# 4      3995 23rd St   San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St   San Francisco        California     USA       Sanchez
# 6   551 Alvarado St   San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#open a web json file!
redditjson = pandas.read_json("https://gist.githubusercontent.com/anonymous/83803696b0e3430a52f1/raw/29f2b252981659dfa6ad51922c8155e66ac261b2/walmart.json")
redditjson
# Out:
#                           address1              city country    id   latitude  \
# 0              8801 Old Seward Hwy         Anchorage      US  6601  61.140770
# 1             1074 N. Muldoon Road         Anchorage      US  6602  61.231079
# 2      1350 S Seward Meridian Pkwy           Wasilla      US  2074  61.568752
# 3                        3101 A St         Anchorage      US  2070  61.192337
# 4                    48 College Rd         Fairbanks      US  6603  64.852867
# 5              8900 Old Seward Hwy         Anchorage      US  2071  61.140263
# 6             18600 Eagle River Rd       Eagle River      US  2188  61.309483
# 7                 6525 Glacier Hwy            Juneau      US  3814  58.358349
# 8             10096 Kenai Spur Hwy             Kenai      US  4474  60.564476
# 9                537 Johansen Expy         Fairbanks      US  2722  64.856873
# 10                7405 Debarr Road         Anchorage      US  4359  61.210758
# ...

# %%
#Show a dataframe
opensemicolontextfile
# Out:
#             Address            City             State Country          Name  \
# ID
# 1      3666 21st St   San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St   San Francisco  California 94114     USA   Super River
# 4      3995 23rd St   San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St   San Francisco        California     USA       Sanchez
# 6   551 Alvarado St   San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#select a portion of it.
opensemicolontextfile.loc[:"3"]
# Out:
#             Address            City             State Country          Name  \
# ID
# 1      3666 21st St   San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St   San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St   San Francisco  California 94114     USA   Super River
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25

# %%
#Set the index to be the address
opensemicolontextfile = opensemicolontextfile.set_index("City")
#Select a single row excluding employees #startrow:endrow, startcolumn:endcolumn
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python35-32\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4066)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:3930)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12408)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12359)()
#
# KeyError: 'Address'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-c55c723cf0eb> in <module>()
# ...
